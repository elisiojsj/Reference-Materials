# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Data Set description:
#
# [Air Quality Data Set](https://archive.ics.uci.edu/ml/datasets/Air+Quality)
# Attribute Information:
#
# - 0 Date (DD/MM/YYYY)
# - 1 Time (HH.MM.SS)
# - 2 True hourly averaged concentration CO in mg/m^3 (reference analyzer)
# - 3 PT08.S1 (tin oxide) hourly averaged sensor response (nominally CO targeted)
# - 4 True hourly averaged overall Non Metanic HydroCarbons concentration in microg/m^3 (reference analyzer)
# - 5 True hourly averaged Benzene concentration in microg/m^3 (reference analyzer)
# - 6 PT08.S2 (titania) hourly averaged sensor response (nominally NMHC targeted)
# - 7 True hourly averaged NOx concentration in ppb (reference analyzer)
# - 8 PT08.S3 (tungsten oxide) hourly averaged sensor response (nominally NOx targeted)
# - 9 True hourly averaged NO2 concentration in microg/m^3 (reference analyzer)
# - 10 PT08.S4 (tungsten oxide) hourly averaged sensor response (nominally NO2 targeted)
# - 11 PT08.S5 (indium oxide) hourly averaged sensor response (nominally O3 targeted)
# - 12 Temperature in Â°C
# - 13 Relative Humidity (%)
# - 14 AH Absolute Humidity

# %%
# Load the data set
df = pd.read_excel('data/AirQualityUCI.xlsx')
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# ...

# %%
df.dtypes
# Out:
# Date             datetime64[ns]
# Time                     object
# CO(GT)                  float64
# PT08.S1(CO)             float64
# NMHC(GT)                  int64
# C6H6(GT)                float64
# PT08.S2(NMHC)           float64
# NOx(GT)                 float64
# PT08.S3(NOx)            float64
# NO2(GT)                 float64
# PT08.S4(NO2)            float64
# PT08.S5(O3)             float64
# T                       float64
# RH                      float64
# AH                      float64
# dtype: object

# %%
# Summary statistics of each column
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.869652  -159.090093     1.865576     894.475963
# std      77.657170   329.817015   139.789093    41.380154     342.315902
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.004958     711.000000
# 50%       1.500000  1052.500000  -200.000000     7.886653     894.500000
# 75%       2.600000  1221.250000  -200.000000    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.604200    794.872333    58.135898   1391.363266   974.951534
# std     257.424561    321.977031   126.931428    467.192382   456.922728
# ...

# %%
# Summary statistics of the column of concentration of CO
df["PT08.S1(CO)"].describe()
# Out:
# count    9357.000000
# mean     1048.869652
# std       329.817015
# min      -200.000000
# 25%       921.000000
# 50%      1052.500000
# 75%      1221.250000
# max      2039.750000
# Name: PT08.S1(CO), dtype: float64

# %%
# Print distribution of concentration of CO
sns.distplot(df["PT08.S1(CO)"].dropna()).set_title("Histogram of concentration of CO")
plt.show()

# %%
# Print boxplot of concentration of CO
sns.boxplot(df["PT08.S1(CO)"].dropna()).set_title("Histogram of concentration of CO")
plt.show()

# %% [markdown]
# With the mean at the point 1048.87 it shows a distribution with a group of outliers concentrated on the same point of -200.00. Due to the fact of being a round number and having some substantial concentration on different date/times it's probably a fail or after reset initial state reading of the sensor. A better analysis is required and it probably can be easily checked in the manual of the sensor.

# %%
# Create a column with the day of the week names for each date
df['day_of_week'] = df['Date'].dt.day_name()
df.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH day_of_week
# 0  13.60  48.875001  0.757754   Wednesday
# ...

# %%
# Show the datatypes of each column
df.dtypes
# Out:
# Date             datetime64[ns]
# Time                     object
# CO(GT)                  float64
# PT08.S1(CO)             float64
# NMHC(GT)                  int64
# C6H6(GT)                float64
# PT08.S2(NMHC)           float64
# NOx(GT)                 float64
# PT08.S3(NOx)            float64
# NO2(GT)                 float64
# PT08.S4(NO2)            float64
# PT08.S5(O3)             float64
# T                       float64
# RH                      float64
# AH                      float64
# day_of_week              object
# dtype: object

# %%
# Plot the boxplots categorized by the day of the week
sns.boxplot(x=df["PT08.S1(CO)"], y=df['day_of_week'])
plt.show()
